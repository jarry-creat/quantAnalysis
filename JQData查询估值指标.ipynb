# %%
from jqdatasdk import *
auth('18161870857','ZTYhyh123123') 
import datetime
import pandas as pd
# 设置行列不忽略
pd.set_option('display.max_rows',10000)
pd.set_option('display.max_columns',1000)

# %%
# 获取股票估值指标
df = get_fundamentals(query(valuation),statDate='2022')
df.head()
# Out:
#          id         code  pe_ratio  turnover_ratio  pb_ratio  ps_ratio  \
# 0  91660420  688555.XSHG   -8.1406          7.5866    0.3981    1.7448
# 1  91660061  688086.XSHG   -1.0437          2.5354    0.3339    1.9869
# 2  91660880  600242.XSHG   -1.0118          6.7881  -13.0983   16.2237
# 3  91657117  002499.XSHE  -11.1873          0.2049  -41.0743    3.0662
# 4  91659940  600311.XSHG   -2.1424          4.6249   -3.9544    0.8888
#
#    pcf_ratio  capitalization  market_cap  circulating_cap  \
# 0    -4.2865       8311.0000      3.1997        4184.2002
# 1    -0.6924      19038.1504      4.6072       13297.1660
# 2    34.8908      45666.5117      5.2516       45129.4531
# 3    53.1325      18900.0000      5.7834       18899.3242
# 4  -169.3201      66560.0000      7.1885       66560.0000
#
#    circulating_market_cap         day  pe_ratio_lyr
# 0                  1.6109  2022-12-30        6.9447
# 1                  3.2179  2022-12-30       -2.0120
# 2                  5.1899  2022-12-30       -1.1124
# 3                  5.7832  2022-12-30      -19.5068
# 4                  7.1885  2022-12-30       -2.4914
